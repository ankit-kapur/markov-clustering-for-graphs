# %% [markdown]
# # Markov graph clustering
#
# ### Importing libraries

# %%
# Numpy
import numpy as np
from numpy import concatenate, array
from numpy.random import randn
# Decimal precision value to display in the matrix
np.set_printoptions(precision=5, suppress=True)

# Matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
# Networkx for plotting the graph
import networkx as nx

# DBscan from sklearn
from sklearn import cluster, datasets
from sklearn.cluster import DBSCAN
from sklearn import metrics
import os
print '\nAll libraries loaded.'
# Out:
# All libraries loaded.

# %% [markdown]
# ## Utility function definitions

# %%
############ Utility functions ############

# Normalization function
def normalize(X):
    return X / X.sum(axis=0)[np.newaxis, :]

# Prune out values that are really close to zero
def prune(X, pruning_threshold):
    for index in np.ndindex(X.shape):
        value = X[index]
        if value <= pruning_threshold:
            X[index] = 0
    return X

# Check if the matrices are equal within a tolerance
def hasConverged(X, Y, convergence_tolerance):
    return np.allclose(X, Y, atol=convergence_tolerance)

# Load data from file and create an adjacency matrix
def getAdjacencyMatrixFromDataset(filePath, delimiter=' ', datatype=int):
    
    # Read from the file
    edges = np.loadtxt(filePath, delimiter=delimiter, dtype=datatype)
    
    # We need to recalibrate the node indexes to go from 1 to N
#     edgeMap = dict((key, value+1) for (value, key) in enumerate(np.unique(edges)))
#     edges_recalibrated = []
#     for pair in edges:
#         edges_recalibrated.append((edgeMap.get(pair[0]), edgeMap.get(pair[1])))
#     edges = np.array(edges_recalibrated)
        
    # Initialize the adjacency matrix A
    numOfNodes = int(np.amax(edges))
    A = np.zeros((numOfNodes, numOfNodes))
    
    for line in edges:
        A[line[0]-1][line[1]-1] = 1
        A[line[1]-1][line[0]-1] = 1
        
    # Add self-loops
    for i in range(0, A.shape[0]):
        A[i][i] = 1
        
    return A, edges

def getNodeToClusterMapping(clusters):
    nodeToClusterMap = {}
    
    for index, cluster in enumerate(clusters):
        for vertex in cluster:
#             if vertex in nodeToClusterMap:
#                 print 'OVERLAP ===>', vertex
            nodeToClusterMap[vertex] = index+1
    return nodeToClusterMap

# Given a transitional matrix, identify and return clusters
def identifyClusters(T, pruning_threshold):
    clusters = set([])
    X = (T>pruning_threshold)

    for i in range(0, X.shape[0]):
        if X[i][i]:
            # X[i] is an attractor. All nodes attracted to it form a cluster
            newCluster = [index for index, x in enumerate(T[i,:]) if x>0]
            clusters.add(tuple(newCluster))
        
    return list(clusters)

# Make a .clu file using the cluster information
def generateCluFile(clusters, filename):
    # Use the cluster data to make a mapping for node # => cluster #
    mapping = getNodeToClusterMapping(clusters)

    # Write to file
    cluFile = open(filename,'w')
    cluFile.write('*Partition PartitionName\n')
    cluFile.write('*Vertices ' + str(len(mapping)) + '\n')
    for key, value in mapping.iteritems():
        cluFile.write(str(value) + '\n')
    cluFile.close()
    #print 'Finished writing to file', filename
    
# Helper function for modularity: Calculates edge-weight summation between 2 clusters
def edgeWeightSummer(cluster1, cluster2, A):
    sum = 0
    for i in range(len(cluster1)):
        v = cluster1[i]
        if cluster1 == cluster2:
            rangeInner = range(i+1, len(cluster2))
        else:
            rangeInner = range(len(cluster2))
        for j in rangeInner:
            u = cluster2[j]
            if (int(A[v][u]) == 1):
                sum += 1
    return sum

# Given a set of clusters, find the modularity score
def getModularity(cluster_set, A):
    modularity = 0
    intracluster_sum = 0
    intercluster_sum = 0
    
    # Find intracluster sum
    for cluster in cluster_set:
        intracluster_sum += edgeWeightSummer(cluster, cluster, A)

    # Find intercluster sum
    for i in range(len(cluster_set)):
        cluster1 = cluster_set[i]
        for j in range(i+1, len(cluster_set)):
            cluster2 = cluster_set[j]
            intercluster_sum += edgeWeightSummer(cluster1, cluster2, A)
    
    modularity = intracluster_sum - intercluster_sum
    return intracluster_sum, intercluster_sum, modularity

# %% [markdown]
# ## Functions for drawing graphs (using matplotlib and networkx)

# %%
# Graph drawing functions
def draw_graph(graph, labels=None, graph_layout='spring',
               node_size=400, node_color='blue', node_alpha=0.3,
               node_text_size=4,
               edge_color='black', edge_alpha=0.3, edge_tickness=1,
               edge_text_pos=0.3,
               text_font='sans-serif', nodespacing=0.02):

    # Define size of the plotted figure
    plt.figure(num=None, figsize=(18.0, 14.0), dpi=580, facecolor='w', edgecolor='k')
    
    # create networkx graph
    G=nx.Graph()

    # add edges
    for edge in graph:
        G.add_edge(edge[0], edge[1])

    # these are different layouts for the network you may try
    # shell seems to work best
    if graph_layout == 'spring':
        graph_pos=nx.spring_layout(G, k=nodespacing)
    elif graph_layout == 'spectral':
        graph_pos=nx.spectral_layout(G)
    elif graph_layout == 'circular':
        graph_pos=nx.circular_layout(G)
    elif graph_layout == 'random':
        graph_pos=nx.random_layout(G)
    elif graph_layout == 'graphviz':
        graph_pos=nx.graphviz_layout(G)
    else:
        graph_pos=nx.shell_layout(G)

    # draw graph
    nx.draw_networkx_nodes(G,graph_pos,node_size=node_size, 
                           alpha=node_alpha, node_color=node_color)
    nx.draw_networkx_edges(G,graph_pos,width=edge_tickness,
                           alpha=edge_alpha,edge_color=edge_color)
    nx.draw_networkx_labels(G, graph_pos,font_size=node_text_size,
                            font_family=text_font)

    if labels is None:
        labels = range(len(graph))

# %% [markdown]
# ## Load the datasets
# ##### We read from the 3 dataset text files, and load the edge information into the edges array. <br>We then use the edge information to generate the adjacency matrices

# %%
# AT & T dataset
A_att, edges_att = getAdjacencyMatrixFromDataset("dataset/new_att.txt")
# Physics collaborations
A_physics, edges_physics = getAdjacencyMatrixFromDataset("dataset/new_collaboration.txt")
# Yeast metabolic network
A_yeast, edges_yeast = getAdjacencyMatrixFromDataset("dataset/new_yeast.txt")
print '\nAll datasets loaded.'
# Out:
# All datasets loaded.

# %% [markdown]
# ## The AT & T dataset (before clustering)

# %%
# Draw graph of original values
draw_graph(edges_att, nodespacing=0.02)
plt.show()

# %% [markdown]
# ## The physics collaborations dataset (before clustering)

# %%
draw_graph(edges_physics, nodespacing=0.02)
plt.show()

# %% [markdown]
# ## The yeast metabolism dataset (before clustering)

# %%
draw_graph(edges_yeast, nodespacing=0.02)
plt.show()

# %% [markdown]
# ## The Markov clustering algorithm

# %%
# Max iterations (for cases where there's no convergence)
maxIterations = 50

def applyMclAlgorithm(A, debug_mode=False, R = 2.0, M_matrix_power_parameter = 4, pruning_threshold = 0.0002,  convergence_tolerance = 0.00000001):
    M = np.array(A)

    # Normalize
    M = normalize(M)
    if debug_mode: print '\nAfter normalization\n', M

    # Keep an original copy
    originalM = np.array(M)

    iterationCount = 1
    while True:
        if debug_mode: print '\n\n======= Iteration', count, '========'
        previousM = np.array(M)

        # Expand
        M = np.linalg.matrix_power(M, M_matrix_power_parameter)
        if debug_mode: print '\nExpanding\n', M

        # Inflate
        M = np.power(M, R)
        if debug_mode: print '\nInflating\n', M

        # Re-normalize
        M = normalize(M)
        if debug_mode: print '\nRenormalizing\n', M

        # Pruning
        M = prune(M, pruning_threshold)
        if debug_mode: print '\nPruning\n', M

        # Check for convergence
        if hasConverged(M, previousM, convergence_tolerance) or iterationCount > maxIterations:
            break

        iterationCount = iterationCount + 1

    clusters = identifyClusters(M, pruning_threshold)
    return clusters, iterationCount

###### MCL parameters ######
R_inflation_param = [1.1, 1.3, 1.5, 1.7, 1.9, 2]
M_expansion_parameter = [2, 3, 4, 5, 6]

###### Function that runs MCL on the datasets for all possible parameter values ######
def runMcl(A, dataset_name):
    
    # Keep track of highest modularity score
    max_modularity = 0
    most_optimal_params = ''
    
    # Make output folder for .clu files
    folderName = 'output/' + dataset_name + '/'
    if not os.path.exists(folderName):
        os.makedirs(folderName)
    
    # Apply MCL to this adjacency matrix A for all param value combinations.
    for M in M_expansion_parameter:
        for R in R_inflation_param:
            
            # Apply MCL and find modularity
            clusters, iterationCount = applyMclAlgorithm(A, R=R, M_matrix_power_parameter=M)
            intracluster_sum, intercluster_sum, modularity = getModularity(clusters, A)
            printstring = 'M = '+str(M) +', R = '+'{0:.1f}'.format(R)+': # of clusters = '+'{0:02d}'.format(len(clusters)) + ', iterations: '+'{0:02d}'.format(iterationCount)
            if iterationCount >= maxIterations:
                printstring += ' -- No convergence'
            else:
                printstring += ', Modularity: '+str(modularity) + ' (intra '+str(intracluster_sum) + ', inter '+str(intercluster_sum)+')'
            print printstring
            
            # Does this set of params have the highest modularity score?
            if (modularity > max_modularity and len(clusters) > 1):
                max_modularity = modularity
                most_optimal_params = printstring
            
            # Make the .clu file
            fileName = folderName + 'M' + str(M) + '_R' + str(int(R*10)) + '.clu';
            generateCluFile(clusters, fileName)
        print ''
    print '\nMost optimal parameters for the', dataset_name, 'dataset:\n', most_optimal_params,'\n'

# %% [markdown]
# ## Applying MCL on the datasets
# #### We now apply ACL on the 3 datasets, using various values of R (inflation parameter), and M (expansion parameter/matrix power).

# %%
import time
start_time = time.time()
print '\n..:: AT & T dataset ::..'
runMcl(A_att, "att")
print("--- %s seconds = AT & T dataset time ---" % (time.time() - start_time))

print '\n..:: Physics collaboration dataset ::..'
start_time = time.time()
runMcl(A_physics, "physics")
print("--- %s seconds = Physics dataset time ---" % (time.time() - start_time))

print '\n..:: Yeast metabolic dataset ::..'
start_time = time.time()
runMcl(A_yeast, "yeast")
print("--- %s seconds = Yeast dataset time ---" % (time.time() - start_time))
start_time = time.time()
# Out:
# ..:: AT & T dataset ::..
# M = 2, R = 1.1: # of clusters = 01, iterations: 51 -- No convergence
# M = 2, R = 1.3: # of clusters = 03, iterations: 42, Modularity: 199 (intra 215, inter 16)
# M = 2, R = 1.5: # of clusters = 07, iterations: 23, Modularity: 81 (intra 213, inter 132)
# M = 2, R = 1.7: # of clusters = 10, iterations: 18, Modularity: 100 (intra 194, inter 94)
# M = 2, R = 1.9: # of clusters = 55, iterations: 15, Modularity: -3 (intra 164, inter 167)
# M = 2, R = 2.0: # of clusters = 55, iterations: 14, Modularity: 11 (intra 150, inter 139)
#
# M = 3, R = 1.1: # of clusters = 01, iterations: 51 -- No convergence
# M = 3, R = 1.3: # of clusters = 01, iterations: 17, Modularity: 228 (intra 228, inter 0)
# M = 3, R = 1.5: # of clusters = 01, iterations: 17, Modularity: 228 (intra 228, inter 0)
# M = 3, R = 1.7: # of clusters = 06, iterations: 17, Modularity: 60 (intra 223, inter 163)
# M = 3, R = 1.9: # of clusters = 06, iterations: 18, Modularity: 149 (intra 190, inter 41)
# M = 3, R = 2.0: # of clusters = 08, iterations: 12, Modularity: 10 (intra 233, inter 223)
#
# M = 4, R = 1.1: # of clusters = 01, iterations: 51 -- No convergence
# M = 4, R = 1.3: # of clusters = 01, iterations: 18, Modularity: 228 (intra 228, inter 0)
# M = 4, R = 1.5: # of clusters = 01, iterations: 10, Modularity: 228 (intra 228, inter 0)
# M = 4, R = 1.7: # of clusters = 02, iterations: 14, Modularity: -95 (intra 408, inter 503)
# M = 4, R = 1.9: # of clusters = 06, iterations: 16, Modularity: 149 (intra 190, inter 41)
# M = 4, R = 2.0: # of clusters = 06, iterations: 11, Modularity: -375 (intra 352, inter 727)
#
# M = 5, R = 1.1: # of clusters = 01, iterations: 51 -- No convergence
# M = 5, R = 1.3: # of clusters = 01, iterations: 19, Modularity: 228 (intra 228, inter 0)
# M = 5, R = 1.5: # of clusters = 01, iterations: 11, Modularity: 228 (intra 228, inter 0)
# M = 5, R = 1.7: # of clusters = 01, iterations: 08, Modularity: 228 (intra 228, inter 0)
# M = 5, R = 1.9: # of clusters = 04, iterations: 13, Modularity: 100 (intra 272, inter 172)
# M = 5, R = 2.0: # of clusters = 04, iterations: 13, Modularity: 179 (intra 218, inter 39)
#
# M = 6, R = 1.1: # of clusters = 01, iterations: 51 -- No convergence
# M = 6, R = 1.3: # of clusters = 01, iterations: 19, Modularity: 228 (intra 228, inter 0)
# M = 6, R = 1.5: # of clusters = 01, iterations: 11, Modularity: 228 (intra 228, inter 0)
# M = 6, R = 1.7: # of clusters = 01, iterations: 08, Modularity: 228 (intra 228, inter 0)
# M = 6, R = 1.9: # of clusters = 01, iterations: 09, Modularity: 228 (intra 228, inter 0)
# M = 6, R = 2.0: # of clusters = 01, iterations: 10, Modularity: 228 (intra 228, inter 0)
#
#
# Most optimal parameters for the att dataset:
# M = 2, R = 1.3: # of clusters = 03, iterations: 42, Modularity: 199 (intra 215, inter 16)
#
# --- 20.2574501038 seconds = AT & T dataset time ---
#
# ..:: Physics collaboration dataset ::..
# M = 2, R = 1.1: # of clusters = 01, iterations: 51 -- No convergence
# M = 2, R = 1.3: # of clusters = 07, iterations: 35, Modularity: -82 (intra 481, inter 563)
# M = 2, R = 1.5: # of clusters = 14, iterations: 23, Modularity: 160 (intra 372, inter 212)
# M = 2, R = 1.7: # of clusters = 18, iterations: 15, Modularity: -54 (intra 455, inter 509)
# M = 2, R = 1.9: # of clusters = 24, iterations: 16, Modularity: 151 (intra 282, inter 131)
# M = 2, R = 2.0: # of clusters = 24, iterations: 16, Modularity: 163 (intra 262, inter 99)
#
# M = 3, R = 1.1: # of clusters = 01, iterations: 51 -- No convergence
# M = 3, R = 1.3: # of clusters = 01, iterations: 22, Modularity: 339 (intra 339, inter 0)
# M = 3, R = 1.5: # of clusters = 06, iterations: 23, Modularity: 201 (intra 404, inter 203)
# M = 3, R = 1.7: # of clusters = 10, iterations: 15, Modularity: 126 (intra 384, inter 258)
# M = 3, R = 1.9: # of clusters = 12, iterations: 14, Modularity: 245 (intra 333, inter 88)
# M = 3, R = 2.0: # of clusters = 14, iterations: 14, Modularity: 225 (intra 306, inter 81)
#
# M = 4, R = 1.1: # of clusters = 01, iterations: 50 -- No convergence
# M = 4, R = 1.3: # of clusters = 01, iterations: 22, Modularity: 339 (intra 339, inter 0)
# M = 4, R = 1.5: # of clusters = 03, iterations: 19, Modularity: 286 (intra 370, inter 84)
# M = 4, R = 1.7: # of clusters = 06, iterations: 20, Modularity: 231 (intra 384, inter 153)
# M = 4, R = 1.9: # of clusters = 09, iterations: 20, Modularity: 298 (intra 320, inter 22)
# M = 4, R = 2.0: # of clusters = 09, iterations: 11, Modularity: 51 (intra 433, inter 382)
#
# M = 5, R = 1.1: # of clusters = 01, iterations: 50 -- No convergence
# M = 5, R = 1.3: # of clusters = 01, iterations: 20, Modularity: 339 (intra 339, inter 0)
# M = 5, R = 1.5: # of clusters = 01, iterations: 14, Modularity: 339 (intra 339, inter 0)
# M = 5, R = 1.7: # of clusters = 03, iterations: 15, Modularity: 330 (intra 336, inter 6)
# M = 5, R = 1.9: # of clusters = 06, iterations: 19, Modularity: 298 (intra 336, inter 38)
# M = 5, R = 2.0: # of clusters = 08, iterations: 13, Modularity: -83 (intra 481, inter 564)
#
# M = 6, R = 1.1: # of clusters = 01, iterations: 50 -- No convergence
# M = 6, R = 1.3: # of clusters = 01, iterations: 20, Modularity: 339 (intra 339, inter 0)
# M = 6, R = 1.5: # of clusters = 01, iterations: 15, Modularity: 339 (intra 339, inter 0)
# M = 6, R = 1.7: # of clusters = 03, iterations: 15, Modularity: 286 (intra 370, inter 84)
# M = 6, R = 1.9: # of clusters = 04, iterations: 15, Modularity: 309 (intra 339, inter 30)
# M = 6, R = 2.0: # of clusters = 05, iterations: 13, Modularity: 224 (intra 393, inter 169)
#
#
# Most optimal parameters for the physics dataset:
# M = 5, R = 1.7: # of clusters = 03, iterations: 15, Modularity: 330 (intra 336, inter 6)
#
# --- 11.9410700798 seconds = Physics dataset time ---
#
# ..:: Yeast metabolic dataset ::..
# M = 2, R = 1.1: # of clusters = 01, iterations: 51 -- No convergence
# M = 2, R = 1.3: # of clusters = 21, iterations: 34, Modularity: 48 (intra 529, inter 481)
# M = 2, R = 1.5: # of clusters = 52, iterations: 36, Modularity: 251 (intra 343, inter 92)
# M = 2, R = 1.7: # of clusters = 84, iterations: 28, Modularity: 175 (intra 305, inter 130)
# M = 2, R = 1.9: # of clusters = 105, iterations: 30, Modularity: 127 (intra 281, inter 154)
# M = 2, R = 2.0: # of clusters = 116, iterations: 29, Modularity: 101 (intra 268, inter 167)
#
# M = 3, R = 1.1: # of clusters = 01, iterations: 51 -- No convergence
# M = 3, R = 1.3: # of clusters = 04, iterations: 28, Modularity: -1053 (intra 911, inter 1964)
# M = 3, R = 1.5: # of clusters = 18, iterations: 24, Modularity: 288 (intra 410, inter 122)
# M = 3, R = 1.7: # of clusters = 40, iterations: 19, Modularity: 220 (intra 399, inter 179)
# M = 3, R = 1.9: # of clusters = 50, iterations: 20, Modularity: 255 (intra 345, inter 90)
# M = 3, R = 2.0: # of clusters = 53, iterations: 21, Modularity: 247 (intra 341, inter 94)
#
# M = 4, R = 1.1: # of clusters = 01, iterations: 51 -- No convergence
# M = 4, R = 1.3: # of clusters = 01, iterations: 18, Modularity: 435 (intra 435, inter 0)
# M = 4, R = 1.5: # of clusters = 09, iterations: 28, Modularity: 350 (intra 429, inter 79)
# M = 4, R = 1.7: # of clusters = 20, iterations: 18, Modularity: 196 (intra 450, inter 254)
# M = 4, R = 1.9: # of clusters = 32, iterations: 16, Modularity: 291 (intra 384, inter 93)
# M = 4, R = 2.0: # of clusters = 37, iterations: 15, Modularity: 276 (intra 375, inter 99)
#
# M = 5, R = 1.1: # of clusters = 01, iterations: 51 -- No convergence
# M = 5, R = 1.3: # of clusters = 01, iterations: 22, Modularity: 435 (intra 435, inter 0)
# M = 5, R = 1.5: # of clusters = 04, iterations: 22, Modularity: 347 (intra 469, inter 122)
# M = 5, R = 1.7: # of clusters = 10, iterations: 19, Modularity: 326 (intra 433, inter 107)
# M = 5, R = 1.9: # of clusters = 20, iterations: 21, Modularity: 332 (intra 385, inter 53)
# M = 5, R = 2.0: # of clusters = 23, iterations: 15, Modularity: 321 (intra 396, inter 75)
#
# M = 6, R = 1.1: # of clusters = 01, iterations: 51 -- No convergence
# M = 6, R = 1.3: # of clusters = 01, iterations: 33, Modularity: 435 (intra 435, inter 0)
# M = 6, R = 1.5: # of clusters = 01, iterations: 18, Modularity: 435 (intra 435, inter 0)
# M = 6, R = 1.7: # of clusters = 09, iterations: 19, Modularity: 320 (intra 456, inter 136)
# M = 6, R = 1.9: # of clusters = 13, iterations: 15, Modularity: 235 (intra 476, inter 241)
# M = 6, R = 2.0: # of clusters = 18, iterations: 14, Modularity: 255 (intra 438, inter 183)
#
#
# Most optimal parameters for the yeast dataset:
# M = 4, R = 1.5: # of clusters = 09, iterations: 28, Modularity: 350 (intra 429, inter 79)
#
# --- 221.409022093 seconds = Yeast dataset time ---
